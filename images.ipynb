# %%
import os
import sys

import cv2
import numpy as np
from PIL import Image

sys.path.append(
    os.path.join(
        os.path.expanduser('~'), 'programming/useful_scripts'
    )
)
import vod_ops

# %%
for im_path in ['att_logo.jpg', 'sprint_logo.jpg', 'T_Mobile_logo_social.jpg', 'verizon_logo.jpg']:
    i = cv2.imread(im_path)
    new_img = np.array(vod_ops.resize_img(i, w=1218, h=898))
    cv2.imwrite(f'bad_scale_{im_path}', new_img)

# %%
i.shape
# Out:
# (1236, 1076, 3)

# %%
big = vod_ops.expand_borders(Image.fromarray(i), by=1000)

# %%
np.array(big).shape
# Out:
# (2736, 2576, 3)

# %%
vod_ops.resize_img(i, w=1218, h=898)
# Out:
# <PIL.Image.Image image mode=RGB size=1218x898 at 0x1AA18B1F438>

# %%
x1 = big

big.crop()
# Out:
# <PIL.Image.Image image mode=RGB size=2576x2736 at 0x1AA18B25F98>
